# %%
#!pip install imblearn

# %%
# In this dataset we see that how many passengers have survived in this accidient ,
# how many of them are male and female and from which fare ticket passengers have survied the most

# %%
#importing the basic libraries 
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
#to load dataset of titanic
df=pd.read_csv('titanic.csv')

# %%
#to see first 5 records
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#to remove unwanted col unnamed permanently 
df.drop('PassengerId',axis=1,inplace=True)

# %%
#to see first 5 records
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
#to see no of rows and cols
df.shape
# Out:
# (891, 11)

# %%
#to check null values
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df['Survived'].value_counts()# output column
# Here as we can see the data in the o/p column is a Balanced data
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#to see the null values in a visualised manner
sb.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#to see % of null values
df.isnull().sum()/df.shape[0]*100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
#to cross check for null values by verifying each columns datatype
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
#we can see that each columns datatypes was correct as its contents 
#also we have null values as nan present in 3 columns which are Age , Cabin , Embarked
#let us now handle the null values now 
#we will fill the null values of Age and Embarked columns as it has null value % less then 50%
#we would be dropping the Cabin column as it has 77% null values

# %%
#to fill nulll values of Age col with mean of that col 
#first find mean 
m=df['Age'].mean()
df['Age'].fillna(m,inplace=True)
#again see null values
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#to see frequncy of Embarked col
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#as we see that S has an higher frequency among others , we will fill the null values with S 
#to replace nan with S in Embarked col permanently
df['Embarked'].replace(np.nan,'S',inplace=True)
df['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#to drop the Cabin Column
df.drop('Cabin',axis=1,inplace=True)

# %%
#again see null values
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
# check the duplicated value
df.duplicated().sum()
# Out:
# 0

# %%
#now we can see that we have handled all the null values and there are no columns left with any null values

# %%
#we dont need Name and Ticket columns , so we drop it
df=df.drop(columns=['Name','Ticket'])

# %%
#lets handle the categorical data

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object

# %%
#we can see object and float dtypes , so we will seperate main df into df_cat and df_num
df_cat=df.select_dtypes(object)
df_cat.dtypes
# Out:
# Sex         object
# Embarked    object
# dtype: object

# %%
df_num=df.select_dtypes(['int64','float64'])
df_num.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# dtype: object

# %%
#call label encoder
from sklearn.preprocessing import LabelEncoder
#convert all object type to numeric type using 
for col in df_cat:
    #create a object for LabelEncoder class
    le=LabelEncoder()
    df_cat[col]=le.fit_transform(df_cat[col])

# %%
df_cat.head()
#we can see its converted
# Out:
#    Sex  Embarked
# 0    1         2
# 1    0         0
# 2    0         2
# 3    0         2
# 4    1         2

# %%
#see the dtypes now
df_cat.dtypes
# Out:
# Sex         int32
# Embarked    int32
# dtype: object

# %%
df_num.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# dtype: object

# %%
#to reduce skewness on continuous numeric value
cols=df_num.columns
print(cols)
for col in cols:
    s=df_num[col].skew()
    print('Col name : {} and skewness : {}'.format(col,s))
    sb.histplot(df_num[col])
    plt.show()
    sb.distplot(df_num[col])
    plt.show()

#here we can every col has +ve skewness and height has min skew so it can be neglected
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')
# Col name : Survived and skewness : 0.4785234382949897
# Col name : Pclass and skewness : -0.6305479068752845
# Col name : Age and skewness : 0.4344880940129925
# Col name : SibSp and skewness : 3.6953517271630565
# Col name : Parch and skewness : 2.7491170471010933
# Col name : Fare and skewness : 4.787316519674893

# %%
#now we will merge both the df(df_cat and df_num) now and hold it into new df
df_new=pd.concat([df_cat,df_num],axis=1)

# %%
df_new.head()
# Out:
#    Sex  Embarked  Survived  Pclass   Age  SibSp  Parch     Fare
# 0    1         2         0       3  22.0      1      0   7.2500
# 1    0         0         1       1  38.0      1      0  71.2833
# 2    0         2         1       3  26.0      0      0   7.9250
# 3    0         2         1       1  35.0      1      0  53.1000
# 4    1         2         0       3  35.0      0      0   8.0500

# %%
#if we want scaling in numpy
from sklearn.preprocessing import StandardScaler
#now create object of standardscaler class
ss=StandardScaler()
df_new=ss.fit_transform(df_new) #converts into np array 
df_new
# Out:
# array([[ 0.73769513,  0.58595414, -0.78927234, ...,  0.43279337,
#         -0.47367361, -0.50244517],
#        [-1.35557354, -1.9423032 ,  1.2669898 , ...,  0.43279337,
#         -0.47367361,  0.78684529],
#        [-1.35557354,  0.58595414,  1.2669898 , ..., -0.4745452 ,
#         -0.47367361, -0.48885426],
#        ...,
#        [-1.35557354,  0.58595414, -0.78927234, ...,  0.43279337,
#          2.00893337, -0.17626324],
#        [ 0.73769513, -1.9423032 ,  1.2669898 , ..., -0.4745452 ,
#         -0.47367361, -0.04438104],
#        [ 0.73769513, -0.67817453, -0.78927234, ..., -0.4745452 ,
#         -0.47367361, -0.49237783]])

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# select input and output columns
x=df.drop('Survived',axis=1) # selecting input 
y=df['Survived']

# %%
#call label encoder
from sklearn.preprocessing import LabelEncoder
#convert all object type to numeric type using 
for col in x:
    #create a object for LabelEncoder class
    le=LabelEncoder()
    x[col]=le.fit_transform(x[col])

# %%
# train_test_split 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((623, 7), (268, 7), (623,), (268,))

# %%
x.columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'], dtype='object')

# %%
x.dtypes
# Out:
# Pclass      int64
# Sex         int32
# Age         int64
# SibSp       int64
# Parch       int64
# Fare        int64
# Embarked    int32
# dtype: object

# %%
# Apply StandardScaler on the x_train,x_test
from sklearn.preprocessing import StandardScaler

# %%
# create an object of StandardScaler class
ss=StandardScaler()

x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %% [markdown]
# # LogisticRegression

# %%
# Perform LogisticRegression on the model 
from sklearn.linear_model import LogisticRegression

# %%
# create an object of LogisticRegression class
lr=LogisticRegression()

# %%
# create a user defined function
def create_model(model): #user defined parameter as object 
    model.fit(x_train,y_train)# training the model 
    y_pred=model.predict(x_test)# testing the model
    print(classification_report(y_test,y_pred))
    print(confusion_matrix(y_test,y_pred))
    return model

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import confusion_matrix

# %%
# select input and output columns
x=df.drop('Survived',axis=1) # selecting input 
y=df['Survived']

# %%
#convert all object type to numeric type using 
for col in x:
    #create a object for LabelEncoder class
    le=LabelEncoder()
    x[col]=le.fit_transform(x[col])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
# create an object of StandardScaler class
ss=StandardScaler()

x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %% [markdown]
# # Decision Tree

# %%
# Perform the DecisionTreeClassifier on the dataset 
from sklearn.tree import DecisionTreeClassifier

# %%
# create an object of DecisionTreeClassifier class
dt=DecisionTreeClassifier()

# %%
# call function
dt=create_model(dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80       153
#            1       0.76      0.64      0.69       115
#
#     accuracy                           0.76       268
#    macro avg       0.76      0.74      0.75       268
# weighted avg       0.76      0.76      0.75       268
#
# [[129  24]
#  [ 41  74]]

# %%
# to check the which feature is more important
IG=dt.feature_importances_
print(IG)
# Out:
# [0.11171034 0.33027867 0.25061866 0.06768667 0.         0.20770811
#  0.03199756]

# %%
columns=x.columns

# %%
# create a dictionary 
dict={'Input column':columns,'Information_gain':IG}
df2=pd.DataFrame(dict)
df2
# Out:
#   Input column  Information_gain
# 0       Pclass          0.111710
# 1          Sex          0.330279
# 2          Age          0.250619
# 3        SibSp          0.067687
# 4        Parch          0.000000
# 5         Fare          0.207708
# 6     Embarked          0.031998

# %%
# to see which columns is more important 
df2.sort_values('Information_gain',ascending=False)
df2
# Out:
#   Input column  Information_gain
# 0       Pclass          0.111710
# 1          Sex          0.330279
# 2          Age          0.250619
# 3        SibSp          0.067687
# 4        Parch          0.000000
# 5         Fare          0.207708
# 6     Embarked          0.031998

# %%
# create a tree 
from sklearn import tree
features=x.columns # here features is user defined object which hold all inputs
fig=plt.figure(figsize=(20,20))
#_=tree.plot_tree(dt,feature_names=features,filled=True)

# %%
# there are limitation in the DecisionTreeClassifier in where it uses all the un-neccsary cols so it 
# create overfitting technique

# %% [markdown]
# # max_depth

# %%
# 1. max_depth parameter 

# no  need to import DecisionTreeClassifier
# create object of DecisionTreeClassifier class
dt1=DecisionTreeClassifier(max_depth=5)# by default it takes : Gini index

# %%
# Now to remove the overfitting here we use Pruning Technique 
# There are two types of Pruning technique
# 1. max_depth  parameter 

# 2. min_sample_leaf

# %%
# train the model 
dt1=create_model(dt1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82       153
#            1       0.81      0.61      0.70       115
#
#     accuracy                           0.77       268
#    macro avg       0.78      0.75      0.76       268
# weighted avg       0.78      0.77      0.77       268
#
# [[137  16]
#  [ 45  70]]

# %%
# create a tree 
from sklearn import tree
features=x.columns # here features is user defined object which hold all inputs
fig=plt.figure(figsize=(20,20))
_=tree.plot_tree(dt1,feature_names=features,filled=True)

# %%
# to check the which feature is more important
IG=dt1.feature_importances_
print(IG)
# Out:
# [0.16270937 0.52668207 0.13480997 0.05878276 0.00852827 0.06524926
#  0.04323831]

# %%
columns=x.columns

# %%
# create a dictionary 
dict={'Input column':columns,'Information_gain':IG}
df1=pd.DataFrame(dict)
df1
# Out:
#   Input column  Information_gain
# 0       Pclass          0.162709
# 1          Sex          0.526682
# 2          Age          0.134810
# 3        SibSp          0.058783
# 4        Parch          0.008528
# 5         Fare          0.065249
# 6     Embarked          0.043238

# %%
df1.sort_values('Information_gain',ascending=False)
# It Arranges the record into descinding order
# Out:
#   Input column  Information_gain
# 1          Sex          0.526682
# 0       Pclass          0.162709
# 2          Age          0.134810
# 5         Fare          0.065249
# 3        SibSp          0.058783
# 6     Embarked          0.043238
# 4        Parch          0.008528

# %% [markdown]
# # min_samples_leaf

# %%
# 2.  min_sample_leaf

# create an object of DecisionTreeClassifier class
dt2=DecisionTreeClassifier(min_samples_leaf=99)

# %%
# call the function 
dt2=create_model(dt2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.98      0.82       153
#            1       0.94      0.43      0.60       115
#
#     accuracy                           0.75       268
#    macro avg       0.82      0.71      0.71       268
# weighted avg       0.80      0.75      0.72       268
#
# [[150   3]
#  [ 65  50]]

# %%
# to check the which feature is more important
IG=dt2.feature_importances_
print(IG)
# Out:
# [0.18541788 0.75697773 0.01591851 0.         0.         0.04168589
#  0.        ]

# %%
columns=x.columns

# %%
# create a dictionary 
dict={'Input column':columns,'Information_gain':IG}
df2=pd.DataFrame(dict)
df2
# Out:
#   Input column  Information_gain
# 0       Pclass          0.185418
# 1          Sex          0.756978
# 2          Age          0.015919
# 3        SibSp          0.000000
# 4        Parch          0.000000
# 5         Fare          0.041686
# 6     Embarked          0.000000

# %%
df2.sort_values('Information_gain',ascending=False)
# It Arranges the record into descinding order
# Out:
#   Input column  Information_gain
# 1          Sex          0.756978
# 0       Pclass          0.185418
# 5         Fare          0.041686
# 2          Age          0.015919
# 3        SibSp          0.000000
# 4        Parch          0.000000
# 6     Embarked          0.000000

# %%
# conclusion here the score we have got in max_depth is good then the result/score we got from min_samples_leaf

# %% [markdown]
# # entropy(max_depth)

# %%
# use entropy method of decisiontree
# create object of DecisionTreeClassifier class
dt3=DecisionTreeClassifier(criterion='entropy',max_depth=5)# by default it takes : Gini index

# %%
# call function
dt3=create_model(dt3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.82       153
#            1       0.85      0.58      0.69       115
#
#     accuracy                           0.78       268
#    macro avg       0.80      0.75      0.76       268
# weighted avg       0.79      0.78      0.77       268
#
# [[141  12]
#  [ 48  67]]

# %%
# create a tree 
from sklearn import tree
features=x.columns # here features is user defined object which hold all inputs
fig=plt.figure(figsize=(20,20))
_=tree.plot_tree(dt3,feature_names=features,filled=True)

# %% [markdown]
# # entropy(min_samples_leaf)

# %%
# use entropy method of decisiontree
# create object of DecisionTreeClassifier class
dt4=DecisionTreeClassifier(criterion='entropy',min_samples_leaf=50)# by default it takes : Gini index

# %%
# call function
dt4=create_model(dt4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.98      0.82       153
#            1       0.94      0.43      0.60       115
#
#     accuracy                           0.75       268
#    macro avg       0.82      0.71      0.71       268
# weighted avg       0.80      0.75      0.72       268
#
# [[150   3]
#  [ 65  50]]

# %%
# create a tree 
from sklearn import tree
features=x.columns # here features is user defined object which hold all inputs
fig=plt.figure(figsize=(20,20))
_=tree.plot_tree(dt4,feature_names=features,filled=True)

# %% [markdown]
# # Ensembling Technique : Random Forest Tree

# %%
# call the package
from sklearn.ensemble import RandomForestClassifier

# %%
# create an object of RandomForestClassifier class
rfc=RandomForestClassifier(n_estimators=10,max_features=4,random_state=1)

# %%
# call function
rfc=create_model(rfc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.86      0.80       153
#            1       0.77      0.60      0.67       115
#
#     accuracy                           0.75       268
#    macro avg       0.75      0.73      0.74       268
# weighted avg       0.75      0.75      0.74       268
#
# [[132  21]
#  [ 46  69]]

# %%
x.shape
# Out:
# (891, 7)

# %%
# Appling Entropy to RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=10,max_features=4,criterion='entropy',random_state=1)
# call function
rfc=create_model(rfc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80       153
#            1       0.77      0.63      0.69       115
#
#     accuracy                           0.76       268
#    macro avg       0.76      0.74      0.75       268
# weighted avg       0.76      0.76      0.76       268
#
# [[132  21]
#  [ 43  72]]

# %% [markdown]
# # ADA boosting - Adapter boosting

# %%
#apply AdaBoostClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
#create object
ada=AdaBoostClassifier(n_estimators=6,random_state=1)
#call function
ada=create_model(ada)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81       153
#            1       0.77      0.65      0.71       115
#
#     accuracy                           0.77       268
#    macro avg       0.77      0.75      0.76       268
# weighted avg       0.77      0.77      0.77       268
#
# [[131  22]
#  [ 40  75]]

# %% [markdown]
# # Gradient Boosting

# %%
#to apply GradientBoostingClassifier on this dataset 
from sklearn.ensemble import GradientBoostingClassifier

# %%
#create object of GradientBoostingClassifier
gbc=GradientBoostingClassifier(random_state=1,n_estimators=98) #n_estimators means no of iterations

#call function
gbc=create_model(gbc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.89      0.81       153
#            1       0.80      0.61      0.69       115
#
#     accuracy                           0.77       268
#    macro avg       0.78      0.75      0.75       268
# weighted avg       0.77      0.77      0.76       268
#
# [[136  17]
#  [ 45  70]]

# %%
#!pip install xgboost

# %%
#to apply XGBClassifier 
from xgboost import XGBClassifier

# %%
#create a object
xgc=XGBClassifier(n_estimators=25,reg_alpha=1,random_state=1)


#call function
xgc=create_model(xgc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83       153
#            1       0.84      0.60      0.70       115
#
#     accuracy                           0.78       268
#    macro avg       0.80      0.76      0.76       268
# weighted avg       0.79      0.78      0.77       268
#
# [[140  13]
#  [ 46  69]]

# %%
# Conclusion here the result we have got by performing all the classification algorithm and the best method we see
# useful is Advanse Boosting

# %% [markdown]
# # SVM

# %%
# call linear svc package
from sklearn.svm import LinearSVC

# %%
# create an object of LinearSVC class
svc=LinearSVC(random_state=1)# hard margin

# call function
svc=create_model(svc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80       153
#            1       0.76      0.66      0.71       115
#
#     accuracy                           0.76       268
#    macro avg       0.76      0.75      0.76       268
# weighted avg       0.76      0.76      0.76       268
#
# [[129  24]
#  [ 39  76]]

# %%
# create an object of LinearSVC class with external error
svc1=LinearSVC(random_state=1,C=0.5)

# call function
svc1=create_model(svc1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80       153
#            1       0.76      0.66      0.71       115
#
#     accuracy                           0.76       268
#    macro avg       0.76      0.75      0.76       268
# weighted avg       0.76      0.76      0.76       268
#
# [[129  24]
#  [ 39  76]]

# %%
#use polynomial kernel function
from sklearn.svm import SVC
#create object ,pass poly in kernel parameter
svc2=SVC(random_state=1,kernel='poly')
#call function
svc2=create_model(svc2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82       153
#            1       0.82      0.61      0.70       115
#
#     accuracy                           0.78       268
#    macro avg       0.79      0.76      0.76       268
# weighted avg       0.78      0.78      0.77       268
#
# [[138  15]
#  [ 45  70]]

# %%
#lets check once with Radial basis
svc3=SVC(random_state=1,kernel='rbf')
#call function
svc3=create_model(svc3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.91      0.81       153
#            1       0.82      0.57      0.67       115
#
#     accuracy                           0.76       268
#    macro avg       0.78      0.74      0.74       268
# weighted avg       0.77      0.76      0.75       268
#
# [[139  14]
#  [ 50  65]]
